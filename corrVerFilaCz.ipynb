# %% [markdown]
# <a href="https://colab.research.google.com/github/Salvini126/informatica/blob/main/corrVerFilaCz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pymongo
import pandas as pd

# %%
client = pymongo.MongoClient("mongodb://webUser:xxx123xxx@cluster0-shard-00-00.algwo.mongodb.net:27017,cluster0-shard-00-01.algwo.mongodb.net:27017,cluster0-shard-00-02.algwo.mongodb.net:27017/?ssl=true&replicaSet=atlas-am4cb3-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.sample_supplies

# %%
doc=db.sales.find_one()
doc
# Out:
# {'_id': ObjectId('5bd761dcae323e45a93ccffe'),
#  'couponUsed': False,
#  'customer': {'age': 61,
#   'email': 'ucikosusu@sid.uz',
#   'gender': 'M',
#   'satisfaction': 1},
#  'items': [{'name': 'notepad',
#    'price': Decimal128('25.83'),
#    'quantity': 5,
#    'tags': ['office', 'writing', 'school']},
#   {'name': 'printer paper',
#    'price': Decimal128('14.6'),
#    'quantity': 2,
#    'tags': ['office', 'stationary']},
#   {'name': 'pens',
#    'price': Decimal128('7.49'),
#    'quantity': 1,
#    'tags': ['writing', 'office', 'school', 'stationary']},
#   {'name': 'backpack',
#    'price': Decimal128('149.09'),
#    'quantity': 4,
#    'tags': ['school', 'travel', 'kids']},
#   {'name': 'laptop',
#    'price': Decimal128('898.84'),
#    'quantity': 1,
#    'tags': ['electronics', 'school', 'office']},
#   {'name': 'binder',
#    'price': Decimal128('21.01'),
#    'quantity': 2,
#    'tags': ['school', 'general', 'organization']},
#   {'name': 'notepad',
#    'price': Decimal128('21.06'),
#    'quantity': 4,
#    'tags': ['office', 'writing', 'school']},
#   {'name': 'envelopes',
#    'price': Decimal128('21.48'),
#    'quantity': 8,
#    'tags': ['stationary', 'office', 'general']},
#   {'name': 'notepad',
#    'price': Decimal128('39.38'),
#    'quantity': 3,
#    'tags': ['office', 'writing', 'school']},
#   {'name': 'binder',
#    'price': Decimal128('13.07'),
#    'quantity': 4,
#    'tags': ['school', 'general', 'organization']}],
#  'purchaseMethod': 'Online',
#  'saleDate': datetime.datetime(2013, 3, 20, 16, 36, 39, 112000),
#  'storeLocation': 'San Diego'}

# %% [markdown]
# 1.le mail degli utenti che hanno usato i coupon per un acquisto

# %%
result=db.sales.find({"couponUsed":True},{"mail":"$customer.email","_id":0})
df = pd.DataFrame(list(result))
df
# Out:
#                   mail
# 0     cauho@witwuta.sv
# 1         beancu@oz.ee
# 2     rutiro@tedrag.ly
# 3     kupeen@gareha.ne
# 4       wir@osibova.aq
# ..                 ...
# 472     kan@lepboil.cf
# 473   etvice@uploli.tv
# 474  tolfop@uwtuiba.bn
# 475        ka@ejeoj.gs
# 476          hud@we.ve
#
# [477 rows x 1 columns]

# %% [markdown]
# 2.le mail degli utenti che hanno comperato articoli per la scuola

# %%
result=db.sales.find({"items.tags":{"$regex":"school"}},{"_id":"$customer.email"})
df = pd.DataFrame(list(result))
df
# Out:
#                      _id
# 0       ucikosusu@sid.uz
# 1       cauho@witwuta.sv
# 2              me@lih.st
# 3         keecade@hem.uy
# 4      worbiduh@vowbu.cg
# ...                  ...
# 4859    timibjup@epce.li
# 4860  zowna@hebsefduf.cd
# 4861     mohofri@cusa.jm
# 4862     ti@buhenogin.sg
# 4863  lihzodud@voblep.ie
#
# [4864 rows x 1 columns]

# %% [markdown]
# 3.gli ordini effettuati nel marzo del 2013

# %%
import datetime
result=db.sales.find({"$and":[{"saleDate":{"$gte":datetime.datetime(2013,3,1)}},{"saleDate":{"$lte":datetime.datetime(2013,3,31)}}]})
df = pd.DataFrame(list(result))
df
# Out:
#                          _id                saleDate  \
# 0   5bd761dcae323e45a93ccffe 2013-03-20 16:36:39.112
# 1   5bd761dcae323e45a93cd078 2013-03-12 09:34:55.659
# 2   5bd761dcae323e45a93cd01f 2013-03-16 11:31:20.572
# 3   5bd761dcae323e45a93cd0cc 2013-03-18 07:12:45.173
# 4   5bd761dcae323e45a93cd0ce 2013-03-01 13:10:43.474
# ..                       ...                     ...
# 64  5bd761deae323e45a93ce226 2013-03-22 14:06:21.976
# 65  5bd761deae323e45a93ce2cc 2013-03-21 16:07:34.820
# 66  5bd761deae323e45a93ce213 2013-03-17 17:25:11.760
# 67  5bd761deae323e45a93ce29f 2013-03-08 20:20:47.152
# 68  5bd761deae323e45a93ce2cb 2013-03-07 07:10:53.504
#
#                                                 items storeLocation  \
# 0   [{'name': 'notepad', 'tags': ['office', 'writi...     San Diego
# 1   [{'name': 'envelopes', 'tags': ['stationary', ...        London
# 2   [{'name': 'binder', 'tags': ['school', 'genera...       Seattle
# 3   [{'name': 'laptop', 'tags': ['electronics', 's...        Denver
# 4   [{'name': 'backpack', 'tags': ['school', 'trav...       Seattle
# ..                                                ...           ...
# 64  [{'name': 'binder', 'tags': ['school', 'genera...        Denver
# 65  [{'name': 'laptop', 'tags': ['electronics', 's...        Denver
# 66  [{'name': 'backpack', 'tags': ['school', 'trav...        Denver
# 67  [{'name': 'laptop', 'tags': ['electronics', 's...        Austin
# 68  [{'name': 'binder', 'tags': ['school', 'genera...        Denver
#
#                                              customer  couponUsed  \
# 0   {'gender': 'M', 'age': 61, 'email': 'ucikosusu...       False
# 1   {'gender': 'F', 'age': 46, 'email': 'jezga@nov...        True
# 2   {'gender': 'F', 'age': 24, 'email': 'fufjoka@z...       False
# 3   {'gender': 'F', 'age': 39, 'email': 'not@gepo....       False
# 4   {'gender': 'M', 'age': 54, 'email': 'oke@bisub...       False
# ..                                                ...         ...
# 64  {'gender': 'F', 'age': 48, 'email': 'donlec@ut...       False
# 65  {'gender': 'M', 'age': 46, 'email': 'so@fot.bg...       False
# 66  {'gender': 'F', 'age': 48, 'email': 'vajdince@...        True
# 67  {'gender': 'M', 'age': 53, 'email': 'majve@udu...       False
# 68  {'gender': 'M', 'age': 68, 'email': 'fibernep@...       False
#
#    purchaseMethod
# 0          Online
# 1        In store
# 2          Online
# 3        In store
# 4          Online
# ..            ...
# 64       In store
# 65       In store
# 66       In store
# 67         Online
# 68         Online
#
# [69 rows x 7 columns]

# %% [markdown]
# 4.l’età media dei clienti

# %%
result=db.sales.aggregate([                                
                                {"$group":{"_id":"null","etaMedia":{"$avg":"$customer.age"}}}
])
df=pd.DataFrame(list(result))
df
# Out:
#     _id  etaMedia
# 0  null   44.7356

# %% [markdown]
# 5.il numero di clienti uomini e donne

# %%
result=db.sales.aggregate([                                
                                {"$group":{"_id":"$customer.gender","total":{"$sum":1}}},
])
df=pd.DataFrame(list(result))
df
# Out:
#   _id  total
# 0   M   2473
# 1   F   2527

# %% [markdown]
# 6.il numero di acquisti per ogni categoria. Ordinare le categorie in ordine decrescente

# %%
result=db.sales.aggregate([       
                                {"$unwind":"$items"},
                                {"$unwind":"$items.tags"},                         
                                {"$group":{"_id":"$items.tags","total":{"$sum":1}}},
                                {"$sort":{"total":-1}}
])
df=pd.DataFrame(list(result))
df
# Out:
#             _id  total
# 0        school  20687
# 1        office  20453
# 2       writing  11431
# 3    stationary  11310
# 4       general   9181
# 5  organization   4676
# 6          kids   2309
# 7        travel   2309
# 8   electronics   2271

# %% [markdown]
# 7.il numero di acquisti per ogni negozio (‘storeLocation’)

# %%
result=db.sales.aggregate([                                
                                {"$group":{"_id":"$storeLocation","total":{"$sum":1}}},
])
df=pd.DataFrame(list(result))
df
# Out:
#          _id  total
# 0   New York    501
# 1     Denver   1549
# 2  San Diego    346
# 3    Seattle   1134
# 4     London    794
# 5     Austin    676

# %% [markdown]
# 8.i negozi in cui sono stati effettuati meno di 100 acquisti

# %%
result=db.sales.aggregate([                                
                                {"$group":{"_id":"$storeLocation","total":{"$sum":1}}},
                                {"$match":{"total":{"$lt":100}}}
])
df=pd.DataFrame(list(result))
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# 9.il negozio in cui sono stati effettuati meno acquisti
